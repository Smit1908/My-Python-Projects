# %%
pip install pyqrcode
# Out:
# ...
#      -------------------------------------- 41.9/41.9 kB 406.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36229 sha256=c6946df77ba13c12c7a33d9291d2a0e31997e7d87b0cbc4ed2f32ee08eb8f7a1
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\da\75\c0\38c7f82750de2725429b6b8571dca254249d73f6c882c5d9b1
# Successfully built pyqrcode
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyqrcode pypng pillow
# Out:
# ...
#      -------------------------------------- 58.1/58.1 kB 382.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyqrcode
from PIL import Image
link = input ("Enter anything to genrate QR:")
qr_code = pyqrcode.create(link)
qr_code.png("QRCode.png", scale=5)
Image.open("QRCode.png")
# Out:
# Enter anything to genrate QR:http://localhost:8888/notebooks/python/Untitled.ipynb?kernel_name=python3
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=285x285>
